# %% [markdown]
# # Hadoop Streaming assignment 3: Name Count
#
# Make WordCount program for all the names in the dataset. Name is a word with the following properties:
#
# 1. The first character is not a digit (other characters can be digits).
# 2. The first character is uppercase, all the other characters that are letters are lowercase.
# 3. There are less than 0.5% occurrences of this word, when this word regardless to its case appears in the dataset and the condition (2) is not met.
#
# Order by quantity, most popular first, output format:
#
# *name < tab > count*
#
# The result is the 5th line in the output.

# %%
# %%writefile name_count_mapper.py

import sys
import re

reload(sys)
sys.setdefaultencoding('utf-8')

def is_name(word):
    if len(word) < 2:
        return False
    return (word[0].isalpha()) and (word[0].isupper()) and (word[1:].islower())

for line in sys.stdin:
    try:
        article_id, text = unicode(line.strip()).split('\t', 1)
    except ValueError as e:
        continue
    words = re.split('\W*\s+\W*', text, flags = re.UNICODE)
    for word in words:
        name_flag = int(is_name(word))
        print "%s\t%d\t%d" % (word.lower(), name_flag, 1)
# Out:
# Writing name_count_mapper.py

# %%
# %%writefile name_count_reducer.py

import sys

current_key = None
word_sum = 0.0
name_sum = 0.0

for line in sys.stdin:
    try:
        key, name_count, word_count = line.strip().split('\t', 2)
        name_count = int(name_count)
        word_count = int(word_count)
    except ValueError as e:
        continue
    if current_key != key:
        if current_key and float(word_sum - name_sum) / word_sum * 100 < 0.5:
            print '%s\t%d' % (current_key, word_sum)
        current_key = key
        name_sum = 0
        word_sum = 0
    name_sum += name_count
    word_sum += word_count
    
if current_key and float(word_sum - name_sum) / word_sum * 100 < 0.5:
    print '%s\t%d' % (current_key, word_sum)
# Out:
# Writing name_count_reducer.py

# %%
# %%writefile name_count_sorting_mapper.py

import sys

for line in sys.stdin:
    try:
        key, count = line.strip().split('\t', 1)
        count = int(count)
        print "%d\t%s" % (count, key)
    except ValueError as e:
        continue
# Out:
# Writing name_count_sorting_mapper.py

# %%
# %%writefile name_count_sorting_reducer.py

import sys

for line in sys.stdin:
    try:
        count, key = line.strip().split('\t', 1)
        count = int(count)
        print "%s\t%d" % (key, count)
    except ValueError as e:
        continue
# Out:
# Writing name_count_sorting_reducer.py

# %%
# %%bash
#
# NAME_COUNT_OUT_DIR="namecount_result"
# NUM_REDUCERS=8
#
# hdfs dfs -rm -r -skipTrash ${NAME_COUNT_OUT_DIR} > /dev/null
#
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapreduce.job.name="Streaming nameCount" \
#     -D mapreduce.job.reduces=${NUM_REDUCERS} \
#     -files name_count_mapper.py,name_count_reducer.py \
#     -mapper "python name_count_mapper.py" \
#     -reducer "python name_count_reducer.py" \
#     -input /data/wiki/en_articles_part \
#     -output ${NAME_COUNT_OUT_DIR} > /dev/null
#
# NAME_COUNT_SORT_OUT_DIR="namecount_sort_result"
# NUM_REDUCERS=1
#
# hdfs dfs -rm -r -skipTrash ${NAME_COUNT_SORT_OUT_DIR} > /dev/null
#
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapreduce.job.name="Streaming nameCountSorting" \
#     -D mapreduce.job.output.key.comparator.class=org.apache.hadoop.mapreduce.lib.partition.KeyFieldBasedComparator \
#     -D map.output.key.field.separator=\t \
#     -D mapreduce.partition.keycomparator.options=-k1,1nr \
#     -D mapreduce.job.reduces=${NUM_REDUCERS} \
#     -files name_count_sorting_mapper.py,name_count_sorting_reducer.py \
#     -mapper "python name_count_sorting_mapper.py" \
#     -reducer "python name_count_sorting_reducer.py" \
#     -input ${NAME_COUNT_OUT_DIR} \
#     -output ${NAME_COUNT_SORT_OUT_DIR} > /dev/null
#
# hdfs dfs -cat ${NAME_COUNT_SORT_OUT_DIR}/part-00000 | head -5 | tail -1
# Out:
# french	5753
# 18/08/02 10:59:54 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 18/08/02 10:59:54 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 18/08/02 10:59:55 INFO mapred.FileInputFormat: Total input files to process : 1
# 18/08/02 10:59:55 INFO mapreduce.JobSubmitter: number of splits:2
# 18/08/02 10:59:55 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1533143790063_0007
# 18/08/02 10:59:55 INFO impl.YarnClientImpl: Submitted application application_1533143790063_0007
# 18/08/02 10:59:55 INFO mapreduce.Job: The url to track the job: http://6b428e5a5e59:8088/proxy/application_1533143790063_0007/
# 18/08/02 10:59:55 INFO mapreduce.Job: Running job: job_1533143790063_0007
# 18/08/02 11:00:01 INFO mapreduce.Job: Job job_1533143790063_0007 running in uber mode : false
# 18/08/02 11:00:01 INFO mapreduce.Job:  map 0% reduce 0%
# 18/08/02 11:00:17 INFO mapreduce.Job:  map 42% reduce 0%
# 18/08/02 11:00:23 INFO mapreduce.Job:  map 55% reduce 0%
# 18/08/02 11:00:29 INFO mapreduce.Job:  map 67% reduce 0%
# 18/08/02 11:00:33 INFO mapreduce.Job:  map 100% reduce 0%
# 18/08/02 11:00:42 INFO mapreduce.Job:  map 100% reduce 13%
# 18/08/02 11:00:43 INFO mapreduce.Job:  map 100% reduce 25%
# 18/08/02 11:00:45 INFO mapreduce.Job:  map 100% reduce 38%
# 18/08/02 11:00:46 INFO mapreduce.Job:  map 100% reduce 75%
# 18/08/02 11:00:49 INFO mapreduce.Job:  map 100% reduce 88%
# 18/08/02 11:00:50 INFO mapreduce.Job:  map 100% reduce 100%
# 18/08/02 11:00:50 INFO mapreduce.Job: Job job_1533143790063_0007 completed successfully
# 18/08/02 11:00:51 INFO mapreduce.Job: Counters: 50
# 	File System Counters
# 		FILE: Number of bytes read=291239559
# 		FILE: Number of bytes written=438172060
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=76874501
# 		HDFS: Number of bytes written=1509249
# 		HDFS: Number of read operations=30
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=16
# 	Job Counters
# 		Killed reduce tasks=1
# 		Launched map tasks=2
# 		Launched reduce tasks=8
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=59596
# 		Total time spent by all reduces in occupied slots (ms)=54020
# 		Total time spent by all map tasks (ms)=59596
# 		Total time spent by all reduce tasks (ms)=54020
# 		Total vcore-milliseconds taken by all map tasks=59596
# 		Total vcore-milliseconds taken by all reduce tasks=54020
# 		Total megabyte-milliseconds taken by all map tasks=61026304
# 		Total megabyte-milliseconds taken by all reduce tasks=55316480
# 	Map-Reduce Framework
# 		Map input records=4100
# 		Map output records=11937375
# 		Map output bytes=121717186
# 		Map output materialized bytes=145592042
# 		Input split bytes=228
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=427176
# 		Reduce shuffle bytes=145592042
# 		Reduce input records=11937375
# 		Reduce output records=135348
# 		Spilled Records=35812125
# 		Shuffled Maps =16
# 		Failed Shuffles=0
# 		Merged Map outputs=16
# 		GC time elapsed (ms)=1309
# 		CPU time spent (ms)=98900
# 		Physical memory (bytes) snapshot=2308988928
# 		Virtual memory (bytes) snapshot=20213084160
# 		Total committed heap usage (bytes)=1542979584
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=76874273
# 	File Output Format Counters
# 		Bytes Written=1509249
# 18/08/02 11:00:51 INFO streaming.StreamJob: Output directory: namecount_result
# 18/08/02 11:00:54 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 18/08/02 11:00:54 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 18/08/02 11:00:55 INFO mapred.FileInputFormat: Total input files to process : 8
# 18/08/02 11:00:55 INFO mapreduce.JobSubmitter: number of splits:8
# 18/08/02 11:00:55 INFO Configuration.deprecation: map.output.key.field.separator is deprecated. Instead, use mapreduce.map.output.key.field.separator
# 18/08/02 11:00:55 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1533143790063_0008
# 18/08/02 11:00:55 INFO impl.YarnClientImpl: Submitted application application_1533143790063_0008
# 18/08/02 11:00:55 INFO mapreduce.Job: The url to track the job: http://6b428e5a5e59:8088/proxy/application_1533143790063_0008/
# 18/08/02 11:00:55 INFO mapreduce.Job: Running job: job_1533143790063_0008
# 18/08/02 11:01:02 INFO mapreduce.Job: Job job_1533143790063_0008 running in uber mode : false
# 18/08/02 11:01:02 INFO mapreduce.Job:  map 0% reduce 0%
# 18/08/02 11:01:07 INFO mapreduce.Job:  map 75% reduce 0%
# 18/08/02 11:01:10 INFO mapreduce.Job:  map 100% reduce 0%
# 18/08/02 11:01:11 INFO mapreduce.Job:  map 100% reduce 100%
# 18/08/02 11:01:12 INFO mapreduce.Job: Job job_1533143790063_0008 completed successfully
# 18/08/02 11:01:12 INFO mapreduce.Job: Counters: 49
# 	File System Counters
# 		FILE: Number of bytes read=1779953
# 		FILE: Number of bytes written=4821837
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=1510153
# 		HDFS: Number of bytes written=1509249
# 		HDFS: Number of read operations=27
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Launched map tasks=8
# 		Launched reduce tasks=1
# 		Data-local map tasks=8
# 		Total time spent by all maps in occupied slots (ms)=21903
# 		Total time spent by all reduces in occupied slots (ms)=2663
# 		Total time spent by all map tasks (ms)=21903
# 		Total time spent by all reduce tasks (ms)=2663
# 		Total vcore-milliseconds taken by all map tasks=21903
# 		Total vcore-milliseconds taken by all reduce tasks=2663
# 		Total megabyte-milliseconds taken by all map tasks=22428672
# 		Total megabyte-milliseconds taken by all reduce tasks=2726912
# 	Map-Reduce Framework
# 		Map input records=135348
# 		Map output records=135348
# 		Map output bytes=1509250
# 		Map output materialized bytes=1779995
# 		Input split bytes=904
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=580
# 		Reduce shuffle bytes=1779995
# 		Reduce input records=135348
# 		Reduce output records=135348
# 		Spilled Records=270696
# 		Shuffled Maps =8
# 		Failed Shuffles=0
# 		Merged Map outputs=8
# 		GC time elapsed (ms)=893
# 		CPU time spent (ms)=12620
# 		Physical memory (bytes) snapshot=2578493440
# 		Virtual memory (bytes) snapshot=18109067264
# 		Total committed heap usage (bytes)=1755316224
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=1509249
# 	File Output Format Counters
# 		Bytes Written=1509249
# 18/08/02 11:01:12 INFO streaming.StreamJob: Output directory: namecount_sort_result
# cat: Unable to write to output stream.
